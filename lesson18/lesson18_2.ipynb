# %%
import numpy as np
import pandas as pd
from pandas import Series

subjects = ['國文', '英文', '數學', '地理', '歷史']

def countFails(s:Series) -> int:
    failSubjects = s[s < 60]
    #print(failSubjects)
    count = failSubjects.count()
    
    return count

def main():
    scores = np.random.randint(50, 101, size=(50, 5))
    scores_df = pd.DataFrame(scores, columns=subjects, index=range(1, 51))

    scores_sum = scores_df.sum(axis=1)
    scores_average = scores_df.mean(axis=1)

    scores_df['總分'] = scores_sum
    scores_df['平均'] = scores_average

    scores_df['不及格的科目數'] = scores_df[subjects].apply(countFails, axis=1)

    display(scores_df)

main()
# Out:
#     國文   英文   數學  地理   歷史   總分    平均  不及格的科目數
# 1   72   75   95  53   71  366  73.2        1
# 2   56   94   90  99   52  391  78.2        2
# 3   86   50   90  80   63  369  73.8        1
# 4   65   60   78  53   83  339  67.8        1
# 5   87   89   71  98   63  408  81.6        0
# 6   89   95   62  89   65  400  80.0        0
# 7   98   83   54  93   89  417  83.4        1
# 8   93   98   62  70   94  417  83.4        0
# 9   67   75   97  52   87  378  75.6        1
# 10  57   76   83  83   55  354  70.8        2
# 11  57   97   86  71   74  385  77.0        1
# 12  71   98   69  50   82  370  74.0        1
# 13  95   63   73  59   60  350  70.0        1
# 14  57   58   57  98   70  340  68.0        3
# 15  95   93   61  61   95  405  81.0        0
# 16  69   86   59  80   59  353  70.6        2
# 17  91   88   69  88   64  400  80.0        0
# 18  81   50   87  79   70  367  73.4        1
# 19  75   83   78  62   68  366  73.2        0
# 20  64   95   82  58   69  368  73.6        1
# 21  62  100   92  69   83  406  81.2        0
# 22  72   68   71  90   59  360  72.0        1
# 23  71   67   57  50   91  336  67.2        2
# 24  87   91   84  90   99  451  90.2        0
# 25  78   55   68  61   90  352  70.4        1
# 26  93   76   85  73   56  383  76.6        1
# 27  50   66   63  58   81  318  63.6        2
# 28  93   59   51  85   68  356  71.2        2
# 29  58   50   86  78   83  355  71.0        2
# 30  96   55   50  75   72  348  69.6        2
# 31  56   76   62  56   60  310  62.0        2
# 32  78   56   54  77   97  362  72.4        2
# 33  90   51   60  52   93  346  69.2        2
# 34  65   80   54  99   62  360  72.0        1
# 35  92   65   99  64   70  390  78.0        0
# 36  97   84   57  70   92  400  80.0        1
# 37  69   95   54  91   92  401  80.2        1
# 38  54   67   84  98   94  397  79.4        1
# 39  99   67   54  65   97  382  76.4        1
# 40  51   70  100  79   82  382  76.4        1
# 41  81   95   86  97   77  436  87.2        0
# 42  75   54   87  76   93  385  77.0        1
# 43  98   97   71  74  100  440  88.0        0
# 44  79   90   72  96   97  434  86.8        0
# 45  69   86   84  61   92  392  78.4        0
# 46  62   84   56  93   69  364  72.8        1
# 47  98   56   91  78   95  418  83.6        1
# 48  82   69   71  57   85  364  72.8        1
# 49  65   78   68  96   80  387  77.4        0
# 50  80   74   92  89   89  424  84.8        0
